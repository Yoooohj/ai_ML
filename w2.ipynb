# %% [markdown]
# <a href="https://colab.research.google.com/github/Yoooohj/ai_ML/blob/main/w2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### w2 task

# %%
dpath = '/content/drive/MyDrive/ai_ml/'

# %%
teammate = pd.DataFrame( {
    'name' : ['윤효정', '김휘중', '좌대현', '조다영', '김가은'],
    '학과' : ['응용통계학과', '경영학과', '응용통계학과', '응용통계학과', '응용통계학과'],
    '학번' : [21,20,19,21,20],
    'hobby' : ['축구하기', '축구보기', '운동하기', '영화보기', '음악듣기']
},
    index = [1,2,3,4,5])

# %%
teammate
# Out:
#   name      학과  학번 hobby
# 1  윤효정  응용통계학과  21  축구하기
# 2  김휘중    경영학과  20  축구보기
# 3  좌대현  응용통계학과  19  운동하기
# 4  조다영  응용통계학과  21  영화보기
# 5  김가은  응용통계학과  20  음악듣기

# %%
teammate.to_csv(dpath + 'w2_teammate.csv', index = True)

# %%
pd.read_csv(dpath + 'w2_teammate.csv', index_col = 0)
# Out:
#   name      학과  학번 hobby
# 1  윤효정  응용통계학과  21  축구하기
# 2  김휘중    경영학과  20  축구보기
# 3  좌대현  응용통계학과  19  운동하기
# 4  조다영  응용통계학과  21  영화보기
# 5  김가은  응용통계학과  20  음악듣기
